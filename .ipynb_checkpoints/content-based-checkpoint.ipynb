# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

ratings=pd.read_csv('olist_order_reviews_dataset.csv')
products=pd.read_csv('olist_products_dataset.csv')
customers=pd.read_csv('olist_customers_dataset.csv')
orders=pd.read_csv('olist_orders_dataset.csv')
orderitems=pd.read_csv('olist_order_items_dataset.csv')
payments=pd.read_csv('olist_order_payments_dataset.csv')
category=pd.read_csv('product_category_name_translation.csv')
geolocation=pd.read_csv('olist_geolocation_dataset.csv')

# %%
df=pd.merge(customers, orders, on='customer_id', how='inner')
df= df.merge(ratings, on="order_id", how='inner')
df= df.merge(orderitems, on="order_id", how='inner')
df= df.merge(products, on="product_id", how='inner')
df= df.merge(payments, on="order_id", how='inner')
df= df.merge(category, on='product_category_name', how='inner')
df.shape
# Out:
# (115609, 37)

# %%
df
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 2       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 3       f0ac8e5a239118859b1734e1087cbb1f  3c799d181c34d51f6d44bbbc563024db
# 4       6bc8d08963a135220ed6c6d098831f84  23397e992b09769faf5e66f9e171a241
# ...                                  ...                               ...
# 115604  e618ce61b7a6c510ada191f657306c68  4b7f26d90bb264ade7e4281db1b739f1
# 115605  6b47c3eea2c418b4ee03f1cc38e30519  215c346bf0164978a8725f01f7715ab4
# 115606  28738edfba72391be47d697e6e7e5770  e839774c9d31569dba47946296e58b33
# 115607  363d3a9b2ec5c5426608688ca033292d  d8bee9ec375c3a0f9ef8ed7456a51dcd
# 115608  919570a26efbd068d6a0f66d5c5072a3  141e824b8e0df709e3fcf6d982225a8e
#
#         customer_zip_code_prefix       customer_city customer_state  \
# 0                          14409              franca             SP
# 1                          68030            santarem             PA
# 2                          68030            santarem             PA
# 3                          92480     nova santa rita             RS
# 4                          25931                mage             RJ
# ...                          ...                 ...            ...
# 115604                     13088            campinas             SP
# 115605                     37150  carmo do rio claro             MG
# 115606                     11035              santos             SP
# 115607                     76940      rolim de moura             RO
# 115608                     71940            brasilia             DF
#
#                                 order_id order_status  \
# 0       00e7ee1b050b8499577073aeb2a297a1    delivered
# 1       c1d2b34febe9cd269e378117d6681172    delivered
# 2       c1d2b34febe9cd269e378117d6681172    delivered
# 3       b1a5d5365d330d10485e0203d54ab9e8    delivered
# 4       2e604b3614664aa66867856dba7e61b7    delivered
# ...                                  ...          ...
# 115604  cc9760bf7b5d5b74c4d1eb1ab6405b50    delivered
# 115605  08322b6d209359f491acb1e5f89cb371    delivered
# 115606  31a2886d02ad2127bfec204da2e93b66    delivered
# 115607  2c4ada2e75c2ad41dd93cebb5df5f023    delivered
# 115608  bede3503afed051733eeb4a84d1adcc5    delivered
#
#        order_purchase_timestamp order_approved_at  \
# 0               16/5/2017 15:05   16/5/2017 15:22
# 1                9/11/2017 0:50   10/11/2017 0:47
# 2                9/11/2017 0:50   10/11/2017 0:47
# 3                7/5/2017 20:11    8/5/2017 22:22
# 4                3/2/2018 19:45    4/2/2018 22:29
# ...                         ...               ...
# 115604          17/7/2018 13:32    18/7/2018 4:35
# 115605          22/8/2018 20:16    24/8/2018 3:05
# 115606          25/7/2018 10:27   25/7/2018 10:35
# 115607          26/1/2017 11:09   26/1/2017 11:22
# 115608          17/9/2017 16:51    19/9/2017 4:05
#
#        order_delivered_carrier_date  ... product_photos_qty product_weight_g  \
# 0                   23/5/2017 10:47  ...                1.0           8683.0
# 1                   22/11/2017 1:43  ...                1.0           8683.0
# 2                   22/11/2017 1:43  ...                1.0           8683.0
# 3                   19/5/2017 20:16  ...                1.0           8683.0
# 4                   19/2/2018 18:21  ...                1.0           8683.0
# ...                             ...  ...                ...              ...
# 115604              19/7/2018 15:00  ...                1.0            267.0
# 115605              24/8/2018 13:57  ...                5.0           6850.0
# 115606              25/7/2018 14:53  ...                2.0            325.0
# 115607              27/1/2017 14:59  ...                1.0           1225.0
# 115608              19/9/2017 20:22  ...                4.0            400.0
#
#        product_length_cm  product_height_cm product_width_cm  \
# 0                   54.0               64.0             31.0
# 1                   54.0               64.0             31.0
# 2                   54.0               64.0             31.0
# 3                   54.0               64.0             31.0
# 4                   54.0               64.0             31.0
# ...                  ...                ...              ...
# 115604              24.0                7.0             13.0
# 115605             105.0                5.0             65.0
# 115606              27.0               10.0             14.0
# 115607              27.0               35.0             15.0
# 115608              26.0               22.0             11.0
#
#        payment_sequential payment_type payment_installments  payment_value  \
# 0                       1  credit_card                    2         146.87
# 1                       1  credit_card                    1         275.79
# 2                       1  credit_card                    1         275.79
# 3                       1  credit_card                    7         140.61
# 4                       1  credit_card                   10         137.58
# ...                   ...          ...                  ...            ...
# 115604                  1       boleto                    1          37.47
# 115605                  1       boleto                    1         306.72
# 115606                  1  credit_card                    1          27.20
# 115607                  1  credit_card                    1         209.06
# 115608                  1       boleto                    1         115.45
#
#        product_category_name_english
# 0                   office_furniture
# 1                   office_furniture
# 2                   office_furniture
# 3                   office_furniture
# 4                   office_furniture
# ...                              ...
# 115604         arts_and_craftmanship
# 115605         arts_and_craftmanship
# 115606         arts_and_craftmanship
# 115607         security_and_services
# 115608         security_and_services
#
# [115609 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state', 'order_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp', 'order_item_id',
#        'product_id', 'seller_id', 'shipping_limit_date', 'price',
#        'freight_value', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'payment_sequential', 'payment_type', 'payment_installments',
#        'payment_value', 'product_category_name_english'],
#       dtype='object')

# %%
#products.drop(['product_name_lenght','product_description_lenght','product_photos_qty','product_weight_g','product_length_cm','product_height_cm','product_width_cm'], axis=1)

# %%
df.dropna(subset= ['order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date'], inplace=True)

# %%
def classify_cat(x):

    if x in ['office_furniture', 'furniture_decor', 'furniture_living_room', 'kitchen_dining_laundry_garden_furniture', 'bed_bath_table', 'home_comfort', 'home_comfort_2', 'home_construction', 'garden_tools', 'furniture_bedroom', 'furniture_mattress_and_upholstery']:
        return 'Furniture'
    
    elif x in ['auto', 'computers_accessories', 'musical_instruments', 'consoles_games', 'watches_gifts', 'air_conditioning', 'telephony', 'electronics', 'fixed_telephony', 'tablets_printing_image', 'computers', 'small_appliances_home_oven_and_coffee', 'small_appliances', 'audio', 'signaling_and_security', 'security_and_services']:
        return 'Electronics'
    
    elif x in ['fashio_female_clothing', 'fashion_male_clothing', 'fashion_bags_accessories', 'fashion_shoes', 'fashion_sport', 'fashion_underwear_beach', 'fashion_childrens_clothes', 'baby', 'cool_stuff', ]:
        return 'Fashion'
    
    elif x in ['housewares', 'home_confort', 'home_appliances', 'home_appliances_2', 'flowers', 'costruction_tools_garden', 'garden_tools', 'construction_tools_lights', 'costruction_tools_tools', 'luggage_accessories', 'la_cuisine', 'pet_shop', 'market_place']:
        return 'Home & Garden'
    
    elif x in ['sports_leisure', 'toys', 'cds_dvds_musicals', 'music', 'dvds_blu_ray', 'cine_photo', 'party_supplies', 'christmas_supplies', 'arts_and_craftmanship', 'art']:
        return 'Entertainment'
    
    elif x in ['health_beauty', 'perfumery', 'diapers_and_hygiene']:
        return 'Beauty & Health'
    
    elif x in ['food_drink', 'drinks', 'food']:
        return 'Food & Drinks'
    
    elif x in ['books_general_interest', 'books_technical', 'books_imported', 'stationery']:
        return 'Books & Stationery'
    
    elif x in ['construction_tools_construction', 'construction_tools_safety', 'industry_commerce_and_business', 'agro_industry_and_commerce']:
        return 'Industry & Construction'

df['product_category']=df.product_category_name_english.apply(classify_cat)

# %%
df.product_category.value_counts()
# Out:
# Electronics                29568
# Furniture                  28050
# Entertainment              13507
# Beauty & Health            13283
# Home & Garden              12848
# Fashion                     9723
# Books & Stationery          3427
# Industry & Construction     1633
# Food & Drinks               1155
# Name: product_category, dtype: int64

# %%
df['product_category']
# Out:
# 0             Furniture
# 1             Furniture
# 2             Furniture
# 3             Furniture
# 4             Furniture
#               ...
# 115604    Entertainment
# 115605    Entertainment
# 115606    Entertainment
# 115607      Electronics
# 115608      Electronics
# Name: product_category, Length: 113194, dtype: object

# %%
df.drop(['product_name_lenght','product_description_lenght','product_photos_qty','product_weight_g','product_length_cm','product_height_cm','product_width_cm','review_creation_date', 'review_answer_timestamp','order_purchase_timestamp', 'order_approved_at',
       'order_delivered_carrier_date', 'order_delivered_customer_date',
       'order_estimated_delivery_date'], axis=1)
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 2       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 3       f0ac8e5a239118859b1734e1087cbb1f  3c799d181c34d51f6d44bbbc563024db
# 4       6bc8d08963a135220ed6c6d098831f84  23397e992b09769faf5e66f9e171a241
# ...                                  ...                               ...
# 115604  e618ce61b7a6c510ada191f657306c68  4b7f26d90bb264ade7e4281db1b739f1
# 115605  6b47c3eea2c418b4ee03f1cc38e30519  215c346bf0164978a8725f01f7715ab4
# 115606  28738edfba72391be47d697e6e7e5770  e839774c9d31569dba47946296e58b33
# 115607  363d3a9b2ec5c5426608688ca033292d  d8bee9ec375c3a0f9ef8ed7456a51dcd
# 115608  919570a26efbd068d6a0f66d5c5072a3  141e824b8e0df709e3fcf6d982225a8e
#
#         customer_zip_code_prefix       customer_city customer_state  \
# 0                          14409              franca             SP
# 1                          68030            santarem             PA
# 2                          68030            santarem             PA
# 3                          92480     nova santa rita             RS
# 4                          25931                mage             RJ
# ...                          ...                 ...            ...
# 115604                     13088            campinas             SP
# 115605                     37150  carmo do rio claro             MG
# 115606                     11035              santos             SP
# 115607                     76940      rolim de moura             RO
# 115608                     71940            brasilia             DF
#
#                                 order_id order_status  \
# 0       00e7ee1b050b8499577073aeb2a297a1    delivered
# 1       c1d2b34febe9cd269e378117d6681172    delivered
# 2       c1d2b34febe9cd269e378117d6681172    delivered
# 3       b1a5d5365d330d10485e0203d54ab9e8    delivered
# 4       2e604b3614664aa66867856dba7e61b7    delivered
# ...                                  ...          ...
# 115604  cc9760bf7b5d5b74c4d1eb1ab6405b50    delivered
# 115605  08322b6d209359f491acb1e5f89cb371    delivered
# 115606  31a2886d02ad2127bfec204da2e93b66    delivered
# 115607  2c4ada2e75c2ad41dd93cebb5df5f023    delivered
# 115608  bede3503afed051733eeb4a84d1adcc5    delivered
#
#                                review_id  review_score  \
# 0       88b8b52d46df026a9d1ad2136a59b30b             4
# 1       7fc63200f12eebb5f387856afdd63db8             1
# 2       7fc63200f12eebb5f387856afdd63db8             1
# 3       251191809e37c1cffc16865947c18a4d             3
# 4       f7123bac5b91a0e2e38d8b41fd1206f4             4
# ...                                  ...           ...
# 115604  012902a4690846e0d3e1cb3a950a1bd0             1
# 115605  10153c6e8359f4e73f3a796cc033c96b             5
# 115606  4db058a0de16a06db15c4217ce42a426             5
# 115607  82ec4a1c6f0134f607033e23431ee298             4
# 115608  1067a7f22781153115958799dc72a8df             1
#
#             review_comment_title  ... shipping_limit_date   price  \
# 0                            NaN  ...     22/5/2017 15:22  124.99
# 1                            NaN  ...     23/11/2017 0:47  112.99
# 2                            NaN  ...     23/11/2017 0:47  112.99
# 3                            NaN  ...     22/5/2017 22:22  124.99
# 4                            NaN  ...     18/2/2018 21:29  106.99
# ...                          ...  ...                 ...     ...
# 115604  Produto ainda não chegou  ...      24/7/2018 4:35    9.80
# 115605                       NaN  ...      29/8/2018 3:05  238.00
# 115606           super recomendo  ...     31/7/2018 10:35   19.80
# 115607                       NaN  ...     30/1/2017 11:09  183.29
# 115608                       NaN  ...      26/9/2017 4:05  100.00
#
#        freight_value product_category_name payment_sequential  payment_type  \
# 0              21.88     moveis_escritorio                  1   credit_card
# 1              24.90     moveis_escritorio                  1   credit_card
# 2              24.90     moveis_escritorio                  1   credit_card
# 3              15.62     moveis_escritorio                  1   credit_card
# 4              30.59     moveis_escritorio                  1   credit_card
# ...              ...                   ...                ...           ...
# 115604         13.68    artes_e_artesanato                  1        boleto
# 115605         68.72    artes_e_artesanato                  1        boleto
# 115606          7.40    artes_e_artesanato                  1   credit_card
# 115607         25.77    seguros_e_servicos                  1   credit_card
# 115608         15.45    seguros_e_servicos                  1        boleto
#
#         payment_installments payment_value  product_category_name_english  \
# 0                          2        146.87               office_furniture
# 1                          1        275.79               office_furniture
# 2                          1        275.79               office_furniture
# 3                          7        140.61               office_furniture
# 4                         10        137.58               office_furniture
# ...                      ...           ...                            ...
# 115604                     1         37.47          arts_and_craftmanship
# 115605                     1        306.72          arts_and_craftmanship
# 115606                     1         27.20          arts_and_craftmanship
# 115607                     1        209.06          security_and_services
# 115608                     1        115.45          security_and_services
#
#        product_category
# 0             Furniture
# 1             Furniture
# 2             Furniture
# 3             Furniture
# 4             Furniture
# ...                 ...
# 115604    Entertainment
# 115605    Entertainment
# 115606    Entertainment
# 115607      Electronics
# 115608      Electronics
#
# [113194 rows x 24 columns]

# %%
df['product_category_name_english']=df['product_category_name_english'].str.replace("_", " ")

# %%
df['product_category_name_english']
# Out:
# 0              office furniture
# 1              office furniture
# 2              office furniture
# 3              office furniture
# 4              office furniture
#                   ...
# 115604    arts and craftmanship
# 115605    arts and craftmanship
# 115606    arts and craftmanship
# 115607    security and services
# 115608    security and services
# Name: product_category_name_english, Length: 113194, dtype: object

# %%
df.head(1)['product_category_name_english']
# Out:
# 0    office furniture
# Name: product_category_name_english, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfv=TfidfVectorizer(min_df=3 , max_features=None, strip_accents='unicode', analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3),stop_words='english')

df['product_category_name_english']=df['product_category_name_english'].fillna('')

# %%
tfv_matrix=tfv.fit_transform(df['product_category_name_english'])

# %%
tfv_matrix
# Out:
# <113194x207 sparse matrix of type '<class 'numpy.float64'>'
# 	with 326403 stored elements in Compressed Sparse Row format>

# %%
tfv_matrix.shape
# Out:
# (113194, 207)

# %%
from sklearn.metrics.pairwise import sigmoid_kernel

sig=sigmoid_kernel(tfv_matrix, tfv_matrix)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28592/2527673229.py in <module>
#       1 from sklearn.metrics.pairwise import sigmoid_kernel
#       2
# ----> 3 sig=sigmoid_kernel(tfv_matrix, tfv_matrix)
#
# D:\Anaconda\lib\site-packages\sklearn\metrics\pairwise.py in sigmoid_kernel(X, Y, gamma, coef0)
#    1069         gamma = 1.0 / X.shape[1]
#    1070
# -> 1071     K = safe_sparse_dot(X, Y.T, dense_output=True)
#    1072     K *= gamma
#    1073     K += coef0
#
# D:\Anaconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# D:\Anaconda\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     154     if (sparse.issparse(a) and sparse.issparse(b)
#     155             and dense_output and hasattr(ret, "toarray")):
# --> 156         return ret.toarray()
#     157     return ret
#     158
#
# D:\Anaconda\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#    1029         if out is None and order is None:
#    1030             order = self._swap('cf')[0]
# -> 1031         out = self._process_toarray_args(order, out)
#    1032         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1033             raise ValueError('Output array must be C or F contiguous')
#
# D:\Anaconda\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1200             return out
#    1201         else:
# -> 1202             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1203
#    1204
#
# MemoryError: Unable to allocate 95.5 GiB for an array with shape (113194, 113194) and data type float64

# %%
cosine_similarity_matrix = cosine_similarity(tfv_matrix, tfv_matrix)
